# %% [markdown]
# # Исследовательский анализ данных компании Procrastinate Pro+

# %% [markdown]
# **Описание проекта**
#
# Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки.
# Ваша задача — разобраться в причинах и помочь компании выйти в плюс.
# Есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# лог сервера с данными об их посещениях,
# выгрузка их покупок за этот период,
# рекламные расходы.
# Вам предстоит изучить:
# откуда приходят пользователи и какими устройствами они пользуются,
# сколько стоит привлечение пользователей из различных рекламных каналов;
# сколько денег приносит каждый клиент,
# когда расходы на привлечение клиента окупаются,
# какие факторы мешают привлечению клиентов.
#
# **Описание данных**
#
# В вашем распоряжении три датасета.
# <p>Файл visits_info_short.csv хранит лог сервера с информацией о посещениях сайта,
# <p>orders_info_short.csv — информацию о заказах,
# <p>costs_info_short.csv — информацию о расходах на рекламу.
#
# Структура visits_info_short.csv:
# - User Id — уникальный идентификатор пользователя,
# - Region — страна пользователя,
# - Device — тип устройства пользователя,
# - Channel — идентификатор источника перехода,
# - Session Start — дата и время начала сессии,
# - Session End — дата и время окончания сессии.
#
# Структура orders_info_short.csv:
# - User Id — уникальный идентификатор пользователя,
# - Event Dt — дата и время покупки,
# - Revenue — сумма заказа.
#
# Структура costs_info_short.csv:
# - dt — дата проведения рекламной кампании,
# - Channel — идентификатор рекламного источника,
# - costs — расходы на эту кампанию.

# %% [markdown]
# **Задачи, поставленные в данном проекте**
#
# **Шаг 1. Загрузите данные и подготовьте их к анализу**
# Загрузите данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
# - визиты: `/datasets/visits_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/visits_info_short.csv);
# - заказы: `/datasets/orders_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/orders_info_short.csv);
# - расходы: `/datasets/costs_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/costs_info_short.csv).
#
# Изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем.
#
# **Шаг 2. Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии**
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
# - get_profiles() — для создания профилей пользователей,
# - get_retention() — для подсчёта Retention Rate,
# - get_conversion() — для подсчёта конверсии,
# - get_ltv() — для подсчёта LTV.
#
# А также функции для построения графиков:
# - filter_data() — для сглаживания данных,
# - plot_retention() — для построения графика Retention Rate,
# - plot_conversion() — для построения графика конверсии,
# - plot_ltv_roi — для визуализации LTV и ROI.
#
# **Шаг 3. Исследовательский анализ данных**
#
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. - Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
#
# **Шаг 4. Маркетинг**
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику. Затем на другом графике визуализируйте динамику изменения расходов во времени по месяцам по каждому источнику.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# **Шаг 5. Оцените окупаемость рекламы**
# - Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
# Ответьте на такие вопросы:
# - Окупается ли реклама, направленная на привлечение пользователей в целом?
# - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# - Чем могут быть вызваны проблемы окупаемости?
# - Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.
#
# **Шаг 6. Напишите выводы**
# - Выделите причины неэффективности привлечения пользователей.
# - Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# ## Загрузка данных и подготовка их к анализу

# %%
#подготовим список библиотек, с которыми будем работать в текущем проекте
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#загрузим данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
visits = pd.read_csv('/datasets/visits_info_short.csv')
pd.set_option('display.max_columns', None)

#выведем то как выглядит таблица в первых трех строках, общую информацию о ней, посчитаем пропуски и дубликаты
print(visits.head(3))
print('----------------------------------------------------------------------')
print('Общая информация о таблице')
print(visits.info())
print('----------------------------------------------------------------------')
print('Информация о пропусках')
print(visits.isna().sum().sort_values(ascending=False))
print('----------------------------------------------------------------------')

print(f'дубликатов найдено:  {visits.duplicated().sum()}')
# Out:
#         User Id         Region  Device  Channel        Session Start  \
# 0  981449118918  United States  iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States  iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States     Mac  organic  2019-05-01 14:09:25
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# ----------------------------------------------------------------------
# Общая информация о таблице
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# ...

# %%
#оформим названия столбцов в соответствии с правилами для удобства использования
visits = visits.rename(columns= {'User Id': 'user_id', 'Region': 'region', 'Device': 'device', \
                                 'Channel': 'channel', 'Session Start': 'sess_start', 'Session End':'sess_end'})
print(visits.columns)
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'sess_start', 'sess_end'], dtype='object')

# %%
# преобразуем данные о времени для дальнейших расчётов
visits['sess_start'] = pd.to_datetime(visits['sess_start'])

visits['sess_end'] = pd.to_datetime(visits['sess_end'])

print(visits[['sess_start','sess_end']])
print('----------------------------------------------------------------------')
print(visits.info())
# Out:
#                 sess_start            sess_end
# 0      2019-05-01 02:36:01 2019-05-01 02:45:01
# 1      2019-05-01 04:46:31 2019-05-01 04:47:35
# 2      2019-05-01 14:09:25 2019-05-01 15:32:08
# 3      2019-05-01 00:29:59 2019-05-01 00:54:25
# 4      2019-05-01 03:33:35 2019-05-01 03:57:40
# ...                    ...                 ...
# 309896 2019-10-31 13:28:12 2019-10-31 14:39:29
# 309897 2019-10-31 22:14:52 2019-10-31 22:39:36
# 309898 2019-10-31 01:40:48 2019-10-31 01:41:31
# 309899 2019-10-31 07:37:34 2019-10-31 07:37:55
# 309900 2019-10-31 14:17:43 2019-10-31 15:17:04
#
# [309901 rows x 2 columns]
# ----------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   user_id     309901 non-null  int64
#  1   region      309901 non-null  object
# ...

# %%
#выведем то как выглядит таблица в первых трех строках, общую информацию о ней, посчитаем пропуски и дубликаты
orders = pd.read_csv('/datasets/orders_info_short.csv')
print(orders.head(3))
print('----------------------------------------------------------------------')
print('Общая информация о таблице')
print(orders.info())
print('----------------------------------------------------------------------')
print('Информация о пропусках')
print(orders.isna().sum().sort_values(ascending=False))
print('----------------------------------------------------------------------')
print(f'дубликатов найдено:  {orders.duplicated().sum()}')
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# ----------------------------------------------------------------------
# Общая информация о таблице
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# None
# ----------------------------------------------------------------------
# Информация о пропусках
# User Id     0
# Event Dt    0
# Revenue     0
# dtype: int64
# ----------------------------------------------------------------------
# дубликатов найдено:  0

# %%
#оформим названия столбцов в соответствии с правилами для удобства использования
orders = orders.rename(columns= {'User Id': 'user_id', 'Event Dt': 'event_dt', 'Revenue': 'revenue'})
print(orders.columns)
# Out:
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')

# %%
# преобразуем данные о времени для дальнейших расчётов
orders['event_dt'] = pd.to_datetime(orders['event_dt'])

print(orders['event_dt'].head(2))
print('----------------------------------------------------------------------')
print(orders.info())
# Out:
# 0   2019-05-01 23:09:52
# 1   2019-05-01 12:24:04
# Name: event_dt, dtype: datetime64[ns]
# ----------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB
# None

# %%
#выведем то как выглядит таблица в первых трех строках, общую информацию о ней, посчитаем пропуски и дубликаты
costs = pd.read_csv('/datasets/costs_info_short.csv')

print(costs.head(3))
print('----------------------------------------------------------------------')
print('Общая информация о таблице')
print(costs.info())
print('----------------------------------------------------------------------')
print('Информация о пропусках')
print(costs.isna().sum().sort_values(ascending=False))
print('----------------------------------------------------------------------')
print(f'дубликатов найдено:  {costs.duplicated().sum()}')
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# ----------------------------------------------------------------------
# Общая информация о таблице
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
# None
# ----------------------------------------------------------------------
# Информация о пропусках
# dt         0
# Channel    0
# costs      0
# dtype: int64
# ----------------------------------------------------------------------
# дубликатов найдено:  0

# %%
#оформим названия столбцов в соответствии с правилами для удобства использования
costs = costs.rename(columns= {'Channel': 'channel'})
print(costs.columns)
# Out:
# Index(['dt', 'channel', 'costs'], dtype='object')

# %%
# преобразуем данные о времени для дальнейших расчётов
costs['dt'] = pd.to_datetime(costs['dt']).dt.date


print(costs['dt'].head(2))
print('----------------------------------------------------------------------')
print(costs.info())
# Out:
# 0    2019-05-01
# 1    2019-05-02
# Name: dt, dtype: object
# ----------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
# None

# %% [markdown]
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
# <p> Вывод к шагу 1
#
# <li> Во всех трех таблицах дубликатов не найдено
# <li> Во всех трех таблицах отсуствуют пропущенные значения
# <li> Столбцы с датами приведены к соответствующему типу данных
# <li> Названия столбцов скорректированы по snake_case </g>
# </div>

# %% [markdown]
# ## Задача функций для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Зададим некоторые функции, которые нам понадобятся для выполнения проекта
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %% [markdown]
# ### Функция get_profiles

# %%
# зададим функции для создания профилей (get_profiles)
def get_profiles(visits, orders, costs):

    # находим параметры первых посещений
    profiles = (
        visits.sort_values(by=["user_id", "sess_start"])
        .groupby("user_id")
        .agg(
            {
                "sess_start": "first",
                "channel": "first",
                "device": "first",
                "region": "first",
            }
        )
        .rename(columns={"sess_start": "first_ts"})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения и первый день месяца, в который это посещение произошло
    profiles["dt"] = profiles["first_ts"].dt.date
    profiles["month"] = profiles["first_ts"].astype("datetime64[M]")

    # добавляем признак платящих пользователей
    profiles["payer"] = profiles["user_id"].isin(orders["user_id"].unique())

    # считаем количество уникальных пользователей с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(["dt", "channel"])
        .agg({"user_id": "nunique"})
        .rename(columns={"user_id": "unique_users"})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    costs = costs.merge(new_users, on=["dt", "channel"], how="left")

    # делим рекламные расходы на число привлечённых пользователей
    costs["acquisition_cost"] = costs["costs"] / costs["unique_users"]

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        costs[["dt", "channel", "acquisition_cost"]], on=["dt", "channel"], how="left"
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles["acquisition_cost"] = profiles["acquisition_cost"].fillna(0.0)

    return profiles

# %%
### Функция get_ltv

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция filter_data

# %%
# функция для сглаживания фрейма
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция plot_ltv_roi

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(8, 24))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(5, 1, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV', fontsize=25)

    # второй график — динамика ltv
    ax2 = plt.subplot(5, 1, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon), fontsize=25)

    # третий график — динамика cac
    ax3 = plt.subplot(5, 1, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей', fontsize=25)


    # четвёртый график — кривые roi
    ax4 = plt.subplot(5, 1, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI', fontsize=25)

    # пятый график — динамика roi
    ax5 = plt.subplot(5, 1, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon), fontsize=25)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция get_conversion

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis=1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция plot_conversion

# %%
# Функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(8, 10))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(2, 1, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(2, 1, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция get_retention

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'sess_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['sess_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция plot_retention

# %%
# Функция для визуализации удержания
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(8, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 1, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # динамика удержания платящих
    ax2 = plt.subplot(2, 1, 2, sharey=ax1)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Создание профилей пользователей

# %% [markdown]
# Составим профили пользователей. Определим минимальную и максимальную даты привлечения пользователей.

# %%
#Зададим условия выполнения функции get_profiles согласно условиям, прописанным в инструкции к выполнению проекта

#момент анализа = 1 ноября 2019
observation_date = datetime(2019, 11, 1).date()
#горизонт анализа = 2 недели. Анализ обязательно нужно провести, не игнорируя горизонт.
horizon_days = 14
ignore_horizon = False

# %%
#посчитаем минималльную дату анализа
min_analysis_date = costs['dt'].min()
min_analysis_date
# Out:
# datetime.date(2019, 5, 1)

# %%
#посчитаем максимальную дату анализа
max_analysis_date = observation_date - timedelta(days = horizon_days - 1)
max_analysis_date
# Out:
# datetime.date(2019, 10, 19)

# %%
#cоставим профили пользователей с помощью приведенной в п.2 функции get_profiles
profiles = get_profiles(visits, orders, costs)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
# <p> Профили пользователей созданы с помощью функции get_profiles
# </div>

# %% [markdown]
# ### Выявление доли платящих пользователей по странам

# %% [markdown]
# Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны.

# %%
# сгруппируем данные из таблицы с профилями пользователей
group_prof_country = profiles.groupby('region').agg({'user_id': 'nunique', 'payer': ['sum', 'mean']})

# переименуем столбцы, чтобы они соответствовали требуемой структуре, уберем двойные названия столбцов
group_prof_country.columns = ['user_id', 'payer_sum', 'payer_mean']

# добавим столбец со значениями user_id в процентах (доли)
group_prof_country['user_id_%'] = (group_prof_country['user_id'] / group_prof_country['user_id'].sum() * 100).round(1)

# добавим столбец со значениями payer_sum в процентах (доли)
group_prof_country['payer_sum_%'] = (group_prof_country['payer_sum'] / group_prof_country['payer_sum'].sum() * 100).round(1)

# добавим столбец со значениями payer_sum в процентах (доли)
group_prof_country['payer_mean_%'] = (group_prof_country['payer_mean'] * 100).round(1)


# изменю порядок столбцов, чтобы было легче сформировать вывод
new_order = ['user_id', 'user_id_%', 'payer_sum', 'payer_sum_%', 'payer_mean','payer_mean_%']
group_prof_country = group_prof_country.reindex(columns=new_order)

print(group_prof_country)

id_sum = group_prof_country['user_id'].sum()
print('-----------------------------------------------------------------')
print(f'Всего игроков {id_sum }')
# Out:
#                user_id  user_id_%  payer_sum  payer_sum_%  payer_mean  \
# region
# France           17450       11.6        663          7.5    0.037994
# Germany          14981       10.0        616          6.9    0.041119
# UK               17575       11.7        700          7.9    0.039829
# United States   100002       66.7       6902         77.7    0.069019
#
#                payer_mean_%
# region
# France                  3.8
# Germany                 4.1
# UK                      4.0
# United States           6.9
# -----------------------------------------------------------------
# Всего игроков 150008

# %% [markdown]
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
# <p>
# <li> Всего в таблице профилей пользователей представлено 15008 профилей. Данные представлены по 4-м странам.
# <li> 2/3 данных представлено игроками из US - свыше 100 000 , остальные пользователи из 3-х стран представлены практически равномерно.
# <li> Наибольшая доля пользователей-плательщиков по странам = 6,9% также из US, остальные страны также имеют практически равную долю платящих пользователей 3,8 - 4,1% из всей выборки.
# <li> Из всех платящих пользователей 77,7% пользоватлей также из US, меньше всего платящих пользователей из Германии - 6,9% от всех платящих.
# </div>

# %% [markdown]
# ### Выявление доли типов устройств платящих пользователей

# %% [markdown]
# Определим, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.
# Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства.

# %%
# сгруппируем данные из таблицы с профилями пользователей
group_prof_device = profiles.groupby('device').agg({'user_id': 'nunique', 'payer': 'sum'})

# добавим столбец со значениями user_id в процентах (доли)
group_prof_device['user_id_%'] = (group_prof_device['user_id'] / group_prof_device['user_id'].sum() * 100).round(1)

# добавим столбец со значениями user_id в процентах (доли)
group_prof_device['payer_%'] = (group_prof_device['payer'] / group_prof_device['payer'].sum() * 100).round(1)

# изменим порядок столбцов, чтобы было легче сформировать вывод
new_order = ['user_id','user_id_%', 'payer', 'payer_%']
group_prof_device = group_prof_device.reindex(columns=new_order)

print(group_prof_device )
# Out:
#          user_id  user_id_%  payer  payer_%
# device
# Android    35032       23.4   2050     23.1
# Mac        30042       20.0   1912     21.5
# PC         30455       20.3   1537     17.3
# iPhone     54479       36.3   3382     38.1

# %% [markdown]
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
# <p>
# <li> Чаще всего пользователи играют на iPhone - 36,3%, на остальных трех типах устройств количество пользователей распределено почти равномерно - 20-23,4%.
# <li> Платящие пользователи также предпочитают iPhone - 38,1%. Меньше всего платящие пользователи используют PC - 17,3%, на Android и Mac доля платящих пользователей примерно равна и составляет 23,1% и 21,5%
#
# </div>

# %% [markdown]
# ### Выявление наиболее эффективных рекламных источников привлечения

# %% [markdown]
# Изучим рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.

# %%
#сгруппируем данные из таблицы с профилями пользователей
group_prof_channel = profiles.groupby('channel').agg({'user_id': 'nunique', 'payer': 'sum'}) \
.sort_values('user_id', ascending = False)

#добавим столбец со значениями user_id в процентах (доли)
group_prof_channel['user_id_%'] = (group_prof_channel['user_id'] / group_prof_channel['user_id'].sum() * 100).round(1)

#добавим столбец со значениями user_id в процентах (доли)
group_prof_channel['payer_%'] = (group_prof_channel['payer'] / group_prof_channel['payer'].sum() * 100).round(1)

#изменим порядок столбцов, чтобы было легче сформировать вывод
new_order = ['user_id','user_id_%', 'payer', 'payer_%']
group_prof_channel = group_prof_channel.reindex(columns=new_order)

print(group_prof_channel)
# Out:
#                     user_id  user_id_%  payer  payer_%
# channel
# organic               56439       37.6   1160     13.1
# FaceBoom              29144       19.4   3557     40.1
# TipTop                19561       13.0   1878     21.1
# OppleCreativeMedia     8605        5.7    233      2.6
# LeapBob                8553        5.7    262      3.0
# WahooNetBanner         8553        5.7    453      5.1
# RocketSuperAds         4448        3.0    352      4.0
# MediaTornado           4364        2.9    156      1.8
# YRabbit                4312        2.9    165      1.9
# AdNonSense             3880        2.6    440      5.0
# lambdaMediaAds         2149        1.4    225      2.5

# %% [markdown]
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
# <p>
# <li> 37,6% всех пользователей перешли из органических источников, т.е. компания не вкладывала средства в их привлечение. Высокая доля пользователей перешла из FaceBoom 19,4% и TipTop - 13%. Меньше всего пользователей перешло из источников: lambdaMediaAds, AdNonSense, YRabbit и MediaTornado - менее 3%.
#
# <li> По платящим пользователям наибольшую долю составлют, те, кто перешли из FaceBoom - то 40,1% всех платящих. TipTop тоже является эффективным источником платящих пользователей - 21,1%. Остальные источники привлекают 1,9 - 5,1% платящих пользователей. Меньше всего платящих пользователей перешли из YRabbit и MediaTornado.
#
# </div>

# %% [markdown]
# ### Общий вывод к шагу 3

# %% [markdown]
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
# <li> Условия задачи говорят о том, что мы рассматриваем данные 01.11.2019 года.
# Горизонт анализа = 2 недели. Следовательно, минимальной датой привлечения является 01.05.2019, максимальной  19.10.2019.
#
# <li> Данные представлены по 4-м странам. 2/3 данных представлено игроками из US - свыше 100 000 , остальные пользователи из 3-х стран представлены практически равномерно. Наибольшая доля пользователей-плательщиков по странам = 6,9% также из US, остальные страны также имеют практически равную долю платящих пользователей 3,8 - 4,1% из всей выборки. Из всех платящих пользователей 77,7% пользоватлей также из US, меньше всего платящих пользователей из Германии - 6,9% от всех платящих.
# <li> Чаще всего пользователи играют на iPhone - 36,3%, на остальных трех типах устройств количество пользователей распределено почти равномерно - 20-23,4%.
# Платящие пользователи также предпочитают iPhone - 38,1%. Меньше всего платящие пользователи используют PC - 17,3%, на Android и Mac доля платящих пользователей примерно равна и составляет 23,1% и 21,5%
#
# <li> 37,6% всех пользователей перешли из органических источников, т.е. компания не вкладывала средства в их привлечение. Высокая доля пользователей перешла из FaceBoom 19,4% и TipTop - 13%. Меньше всего пользователей перешло из источников: lambdaMediaAds, AdNonSense, YRabbit и MediaTornado - менее 3%.
# По платящим пользователям наибольшую долю составлют, те, кто перешли из FaceBoom - то 40,1% всех платящих. TipTop тоже является эффективным источником платящих пользователей - 21,1%. Остальные источники привлекают 1,9 - 5,1% платящих пользователей. Меньше всего платящих пользователей перешли из YRabbit и MediaTornado.
#
# </div>

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# ### Выявление источников, на которые больше всего распределяется рекламных средств

# %% [markdown]
# Посчитаем общую сумму расходов на маркетинг.

# %%
sum_costs = round(costs['costs'].sum(), 1)
print(f'Общая стоимость расходов на маркетинг = {sum_costs}')
# Out:
# Общая стоимость расходов на маркетинг = 105497.3

# %%
'''оценим разбивку по источникам, на которые распределяются средства 
и выясним сколько денег потратили на каждый источник'''

group_costs_channel=costs.groupby('channel').agg({'costs': 'sum'}).sort_values(by='costs', ascending=False)
group_costs_channel['costs_%'] = (group_costs_channel['costs'] / group_costs_channel['costs'].sum() * 100).round(1)
print(group_costs_channel)
# Out:
#                        costs  costs_%
# channel
# TipTop              54751.30     51.9
# FaceBoom            32445.60     30.8
# WahooNetBanner       5151.00      4.9
# AdNonSense           3911.25      3.7
# OppleCreativeMedia   2151.25      2.0
# RocketSuperAds       1833.00      1.7
# LeapBob              1797.60      1.7
# lambdaMediaAds       1557.60      1.5
# MediaTornado          954.48      0.9
# YRabbit               944.22      0.9

# %% [markdown]
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
# <p>
# <li> Больше всего средств вкладывается в 2 источника - TipTop и FaceBoom 54751 и 32455, это 51,9% и 30,8% от всего бюджета, при этом FaceBoom как мы выясними в пункте выше является более эффективным источником привлечения платящих пользователей, чем TipTop.
#
# <li> Самыми неэффективными истониками привлечения являются MediaTornado и YRabbit, но в них вкладывается и меньше всего средств по 954 и 944 - это 0,9% от бюджета
#
# </div>

# %% [markdown]
# ### Визуализация динамики изменения расходов во времени и по источникам

# %% [markdown]
# Построим график с визуализацией динамики изменения расходов во времени по неделям по каждому источнику.
# Визуализируем динамику изменения расходов во времени по месяцам по каждому источнику.

# %%
#создадим столбцы с неделей и месяцем
costs['dt'] = pd.to_datetime(costs['dt'])
costs['month'] = costs['dt'].dt.month
costs['week'] = costs['dt'].dt.isocalendar().week

# %%
#сгруппируем данные по месяцу, в который производились расходы на рекламу
group_costs_month=costs.groupby('month').agg({'costs': 'sum'})
group_costs_month['costs_%'] = (group_costs_month['costs'] / group_costs_month['costs'].sum() * 100).round(1)
print(group_costs_month)
# Out:
#            costs  costs_%
# month
# 5       9978.570      9.5
# 6      15090.045     14.3
# 7      16447.060     15.6
# 8      20657.870     19.6
# 9      22441.340     21.3
# 10     20882.415     19.8

# %%
sns.barplot(x=group_costs_month.index, y='costs', data=group_costs_month)
plt.xlabel('Month')
plt.ylabel('Costs')
plt.title('Group Costs per Month')
plt.show()

# %% [markdown]
# С мая по сентябрь заметно увеличение общего рекламного бюджета с каждым месяцем, однако в октябре расходы начали снижаться, по сравнению с сентябрем

# %%
group_costs_week=costs.groupby('week').agg({'costs': 'sum'})
group_costs_week['costs_%'] = (group_costs_week['costs'] / group_costs_week['costs'].sum() * 100).round(1)
print(group_costs_week)
# Out:
#          costs  costs_%
# week
# 18    1455.640      1.4
# 19    2031.820      1.9
# 20    1976.320      1.9
# 21    2297.120      2.2
# 22    3427.075      3.2
# 23    2915.740      2.8
# 24    2706.390      2.6
# 25    3421.390      3.2
# 26    4837.120      4.6
# 27    4660.335      4.4
# 28    3516.835      3.3
# 29    3039.780      2.9
# 30    3445.460      3.3
# 31    4609.530      4.4
# 32    4446.835      4.2
# 33    4703.960      4.5
# 34    4670.370      4.4
# 35    4732.160      4.5
# 36    4280.635      4.1
# 37    4227.870      4.0
# 38    5473.535      5.2
# 39    6784.580      6.4
# 40    6365.370      6.0
# 41    5190.355      4.9
# 42    4679.935      4.4
# 43    5601.140      5.3

# %% [markdown]
# Так как данных достаточно много - лучше всего посмотреть изменения на графике

# %%
sns.barplot(x=group_costs_week.index, y='costs', data=group_costs_week)
plt.xlabel('Week')
plt.ylabel('Costs')
plt.title('Group Costs per Week')
plt.show()

# %% [markdown]
# Больше всего денежных средств из общего рекламного бюджета вкладывалось в 38-40 недели. Менье всего в 18-21 недели.

# %%
#создадим функцию для визуализации данных маркетинговых расходов по источникам
def plot_costs_m(df):
    df.pivot_table(
        index='month',
        columns='channel',
        values='costs',
        aggfunc='sum',
    ).plot(figsize=(10, 6), grid=True)

    plt.title('Изменение трат по месяцам')
    plt.xlabel('Месяц')
    plt.ylabel('Расходы')
    plt.show()
    
#обработаем функцией таблицу costs
plot_costs_m(costs)

# %%
def plot_costs_w(df):
    df.pivot_table(
        index='week',
        columns='channel',
        values='costs',
        aggfunc='sum',
    ).plot(figsize=(10, 6), grid=True)

    plt.title('Изменение трат по неделям')
    plt.xlabel('Неделя')
    plt.ylabel('Расходы')
    plt.show()

#обработаем функцией таблицу costs
plot_costs_w(costs)

# %% [markdown]
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
# <p>
# <li> С мая по сентябрь заметно увеличение общего рекламного бюджета с каждым месяцем, однако в октябре расходы начали снижаться, по сравнению с сентябрем. Больше всего денежных средств из общего рекламного бюджета вкладывалось в 38-40 недели. Меньше всего в 18-21 недели.
# <li> Ежемесячгые расходы на канал привлечени TipTop увеличиваются почти на 200 000 ежемесячно, за последний месяц расходы на этот источник уменьшились, но по-прежнему остаются самыми высокими среди других. Больше всего денежных средств  в этот источник вкладывалось на 37-41 неделе. С 31-ой по 37-ую не менялся, оставаясь стабильно высочайшим.
# <li> Наиболее эффективный источник привлечения платящих пользователей FaceBoom получает меньше бюджет на рекламу и размер бюджета несущественно менялся с июня по октябрь.Денежные средства в этот источник расходуются менее стабильно, например, после пикового бюджетирования на 26-27 неделе следует спад размера бюджета на 29-ой неделе (т.е. выделялся меньший бюджет, чем до 26-ой.
# </div>

# %% [markdown]
# ### Вычисление стоимости привлечения одного пользователя

# %% [markdown]
# Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.

# %%
# находим LTV с разбивкой по каналам привлечения
dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

# находим максимальную дату привлечения из сырых данных LTV
max_acquitision_dt = ltv_raw['dt'].max()

# отсекаем профили, которые пришли позднее этой даты
ltv_profiles = profiles.query('dt <= @max_acquitision_dt')

# сгруппируем число пользователей по дате
ltv_profiles.groupby('dt').agg({'user_id': 'nunique'})
# Out:
#             user_id
# dt
# 2019-05-01      909
# 2019-05-02      758
# 2019-05-03      849
# 2019-05-04     1015
# 2019-05-05      970
# ...             ...
# 2019-10-15      674
# 2019-10-16      656
# 2019-10-17      703
# 2019-10-18      911
# 2019-10-19      911
#
# [172 rows x 1 columns]

# %%
#посчитает среднюю стоимость привлечения одного клиента по каналам привлечения

cac = (
    ltv_profiles.groupby('channel')
    .agg({'acquisition_cost': 'mean'})
    .rename(columns={'acquisition_cost': 'cac'})
    .sort_values(by='cac', ascending=False)
)
print(round(cac, 2))


print('---------------------------------------------------------------------------------------')

# средний CAC по всему проекту без органических пользователей
cac_no_organic = (ltv_profiles.query('channel != "organic"').agg({'acquisition_cost': 'mean'}))
print(f'Средняя стоимость привлечения одного пользователя = {round(cac_no_organic, 2)}')
# Out:
#                      cac
# channel
# TipTop              2.76
# FaceBoom            1.11
# AdNonSense          1.01
# lambdaMediaAds      0.73
# WahooNetBanner      0.60
# RocketSuperAds      0.42
# OppleCreativeMedia  0.25
# MediaTornado        0.22
# YRabbit             0.22
# LeapBob             0.21
# organic             0.00
# ---------------------------------------------------------------------------------------
# Средняя стоимость привлечения одного пользователя = acquisition_cost    1.12
# dtype: float64

# %% [markdown]
# Дороже всего обходятся клиенты из источника TipTop - 2,76 ,при этом компания тратит на этот источник больше всего средств, хотя он в два раза менее эффективен по привлечению платящих пользователей, чем источник FaceBoom.

# %%
#выведем динамику САС в виде графика

profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(15, 10))
plt.ylabel('CAC')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>☀️
#
# Хочу обратить твоё внимание на изменение `CAC` Tip Top, посмотри ниже на динамику `CAC` по всему проекту, увидишь схожую динамику, это вклад `Tip Top`

# %% [markdown]
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
#     На графике становится оцевидным, что расходы на одного пользователя из источника TipTop росли почти каждый месяц.
# По остальным источникам - таких резких скачков нет, CAC по ним стабилен на протяжении всего периода анализа.</div>

# %% [markdown]
# ### Общий вывод к шагу 4

# %% [markdown]
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
# <p>
# <li> Больше всего средств вкладывается в 2 источника привлечепния клиентов - TipTop и FaceBoom 54751 и 32455, это 51,9% и 30,8% от всего бюджета, при этом FaceBoom как мы выясними в пункте выше является более эффективным источником привлечения платящих пользователей, чем TipTop.
# <li> Самыми неэффективными истониками привлечения являются MediaTornado и YRabbit, но в них вкладывается и меньше всего средств по 954 и 944 - это 0,9% от бюджета
#
# <li> С мая по сентябрь заметно увеличение общего рекламного бюджета с каждым месяцем, однако в октябре расходы начали снижаться, по сравнению с сентябрем. Больше всего денежных средств из общего рекламного бюджета вкладывалось в 38-40 недели. Меньше всего в 18-21 недели.
# <li> Ежемесячгые расходы на канал привлечени TipTop увеличиваются почти на 200 000 ежемесячно, за последний месяц расходы на этот источник уменьшились, но по-прежнему остаются самыми высокими среди других. Больше всего денежных средств  в этот источник вкладывалось на 37-41 неделе. С 31-ой по 37-ую не менялся, оставаясь стабильно высочайшим.
# <li> Наиболее эффективный источник привлечения платящих пользователей FaceBoom получает меньше бюджет на рекламу и размер бюджета несущественно менялся с июня по октябрь.Денежные средства в этот источник расходуются менее стабильно, например, после пикового бюджетирования на 26-27 неделе следует спад размера бюджета на 29-ой неделе (т.е. выделялся меньший бюджет, чем до 26-ой.
#
# <li> Дороже всего компании обходятся клиенты из источника TipTop - CAC = 2,76, при этом компания тратит на этот источник больше всего средств, хотя он в два раза менее эффективен по привлечению платящих пользователей, чем источник FaceBoom.
# <li> Расходы на одного пользователя из источника TipTop росли почти каждый месяц. По остальным источникам - таких резких скачков нет, CAC по ним стабилен на протяжении всего периода анализа.
#
# </div>

# %% [markdown]
# ## Оценка окупаемость рекламы

# %% [markdown]
# ### Общий анализ LTV и ROI

# %%
#т.к. компания не вкладывает деньги в органические источники - исключим их из анализа
profiles = profiles.query('channel != "organic"')

# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# <div class="alert alert-block" style="background-color: gray">
# <g>я умышленно поменяла масштаб отображения графиков и расположение в subplot, потому что плохо вижу
# </div>

# %% [markdown]
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
# <li> LTV (общая сумма денег, которую один клиент в среднем приносит компании со всех своих покупок) стабильно растет.
# <li> ROI (окупаемость инвестиций) находится ниже уровня окупаемости.
# <li> Динамика ROI пользователей на 14-й день падаетс каждым месяцем.
# </div>

# %% [markdown]
# ### Общиц анализ конверсии и удержания

# %% [markdown]
# Проверим конверсию пользователей и динамику её изменения.
# Построим и изучим графики конверсии.

# %%
#оставим критерий dimensions пустым, чтобы увидеть общую конверсию
dimensions = []
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Общая конверсия пользователей чуть выше 8%. Динамика конверсии на 14-ый день по месяцам не совсем стабильна. Под конец месяца существенно снижается - в июне, июле и августе.

# %%
#оставим критерий dimensions пустым, чтобы увидеть общее удержание пользователей
dimensions = []
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# По графику видно, что общая динамика удержания платящих пользователей за две недели падает почти в 4 раза.

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по устройствам

# %%
#добавляем критерий для группировки
dimensions = ['device']

# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)
# строим графики
plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# считаем конверсию
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)
# строим графики конверсии
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# считаем удержание
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)
# строим графики удержания
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
# <p> Меньше всего LTV (пожизненная ценность) у пользователей с PC, остальные девайсы показывают схожую динамику LTV.
# Динамика стоимости привлечения пользователей на iPhone и на MaC практически идентична, но растет быстрее остальных.
# Самую низкую днамику стоимости привлечения показывает PC, но стоит учесть, что окупаемость инвестиций на PC выше уровня окупаемости, для остальных типов устройств - ниже. Динамика ROI в последние в месяцы на PC существенно снижается. По остальным типам устройств также наблюдается снижение, но более плавное из месяца в месяц.
#
# Самую низкую конвесию показывают пользователи, использующие PC. Самую высокую конверсию показывают пользователи с типам устройств Mac и iPhone.
#
# Лучшее удержание показывают пользователи на PC, но оно не существенно отличается от других типов устройств.
# </div>

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по странам

# %%
#добавляем критерий для группировки
dimensions = ['region']

# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)
# строим графики
plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# считаем конверсию
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)
# строим графики конверсии
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# считаем удержание
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)
# строим графики удержания
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
# Пожизненная ценность клиента самая высокая у пользователей из US, по остальным странам схожая динамика LTV
# Динамика LTV подвержена сезонности и стабильна.
#
# Динамика стоимости привлечения клиентов по US аномальная по сравнению с другими странами - из месяца в месяц стоимость привлечения увеличивается практически на одинаковую величину, в других странах динамика более стабильна и не имеет таких явных скачков повышения.
#
# Реклама окупается во всех регионах, кроме US, не смотря на самые высокие завтраты на рекламу там относительно других стран.
#
# Динамика ROI по US на 14-ый день снижается с каждым месяцем.
#
# Самая высокая конверсия пользователей в US, у остальных стран примерно в три раза меньше.
#
# Самое низкое удержание платящих пользователей наблюдается в US,в остальных странах на 1/3 выше.
# Динамика удержания на 14-ый день содержит неполные данные, поэтому визуализируется в прерывистых графиках по всем странам, кроме US.
# </div>

# %% [markdown]
# ### Анализ окупаемости рекламы с разбивкой по рекламным каналам

# %%
#добавляем критерий для группировки
dimensions = ['channel']

# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)
# строим графики
plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# считаем конверсию
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions=dimensions
)
# строим графики конверсии
plot_conversion(conversion_grouped, conversion_history, horizon_days)

# считаем удержание
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions=dimensions
)
# строим графики удержания
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
# Самую высокую пожизненную ценность имеют клиенты из LambdaMediaAds и TipTop.
# Динамика стоимости привлечения пользователей наиболее высокая у канала TipTop. Но высокие расходы не привели к окупаемости этого источника привлечения.
# Самая высокая конверсия пользователей у источников FaceBoom, AdNonSense и LambdaMediaAds, но самое низкое удержание платящих источников - FaceBoom и AdNonSense.
#
# Общий тренд по динамике привлечения на 14-ый день явно можно отследить у FaceBoom и TipTop. Второй источник имеет более скачкообразный характер и только в последние 2 месяца выравнивается на один уровень. FaceBoom же имеет более плавный характер динамики удержания.
# </div>

# %% [markdown]
# ### Общий вывод к шагу 5

# %% [markdown]
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
#
# <li> LTV (общая сумма денег, которую один клиент в среднем приносит компании со всех своих покупок) стабильно растет.
# <li> ROI (окупаемость инвестиций) находится ниже уровня окупаемости. Динамика ROI пользователей на 14-й день падаетс каждым месяцем, а стоимость привлечения пользователей растет. За исследуемое время реклама так и не окупилась.
#
# Общая конверсия пользователей чуть выше 8%. Динамика конверсии на 14-ый день по месяцам не совсем стабильна. Под конец месяца существенно снижается - в июне, июле и августе. общая динамика удержания платящих пользователей за две недели падает почти в 4 раза.
#
# <li> LTV
# <p> Меньше всего LTV (пожизненная ценность) у пользователей с PC, остальные девайсы показывают схожую динамику LTV.
# <p> Пожизненная ценность клиента самая высокая у пользователей из US, по остальным странам схожая динамика LTV.
# <p> Самую высокую пожизненную ценность имеют клиенты из LambdaMediaAds и TipTop.
# Динамика LTV подвержена сезонности и стабильна.
#
#
# <li> Динамика стоимости привлечения пользователей
# <p> Динамика стоимости привлечения пользователей на iPhone и на MaC практически идентична, но растет быстрее остальных.
# Самую низкую днамику стоимости привлечения показывает PC, но стоит учесть, что окупаемость инвестиций на PC выше уровня окупаемости, для остальных типов устройств - ниже.
# <p> Динамика стоимости привлечения клиентов по US аномальная по сравнению с другими странами - из месяца в месяц стоимость привлечения увеличивается практически на одинаковую величину, в других странах динамика более стабильна и не имеет таких явных скачков повышения.
# <p> Динамика стоимости привлечения пользователей наиболее высокая у канала TipTop. Но высокие расходы не привели к окупаемости этого источника привлечения.
#
# <li> Динамика ROI
# <p> Динамика ROI в последние в месяцы на PC существенно снижается. По остальным типам устройств также наблюдается снижение, но более плавное из месяца в месяц.
# Реклама окупается во всех регионах, кроме US, не смотря на самые высокие завтраты на рекламу там относительно других стран.
# Динамика ROI по US на 14-ый день снижается с каждым месяцем.
#
#
# <li> Конверсия
# <p> Самую низкую конвесию показывают пользователи, использующие PC. Самую высокую конверсию показывают пользователи с типам устройств Mac и iPhone.
# <p> Самая высокая конверсия пользователей в US, у остальных стран примерно в три раза меньше.
# <p> Самая высокая конверсия пользователей у источников FaceBoom, AdNonSense и LambdaMediaAds, но самое низкое удержание платящих источников - FaceBoom и AdNonSense.
#
# <li> Удержание
# Лучшее удержание показывают пользователи на PC, но оно не существенно отличается от других типов устройств.
# Самое низкое удержание платящих пользователей наблюдается в US,в остальных странах на 1/3 выше.
#
# </div>

# %% [markdown]
# ## Общие выводы по проекту
#
# <div class="alert alert-block" style="background-color: gainsboro">
# <g>
# <li> В проекте были проанализированы данные с 01.11.2019 года, горизонт анализа - 2 недели. Минимальная дата привлечения пользователей - 01.05.2019, максимальная - 19.10.2019.
#
# Данные представлены по 4 странам. Большая часть данных (2/3) относится к пользователям из США (более 100 000), остальные страны представлены примерно одинаково. США также имеют наибольшую долю платящих пользователей (6,9%), а остальные страны - примерно равные доли платящих пользователей (3,8-4,1%).
#
# Наиболее популярное устройство для игры - iPhone (36,3%), остальные устройства распределены примерно равномерно (20-23,4%). Платящие пользователи также предпочитают iPhone (38,1%). Наименьший процент платящих пользователей использует PC (17,3%), на Android и Mac доли платящих пользователей примерно одинаковы (23,1% и 21,5%).
#
# 37,6% всех пользователей пришли из органических источников. Самые эффективные источники - FaceBoom (19,4%) и TipTop (13%). Наибольшую долю платящих пользователей составляют те, кто пришел из FaceBoom (40,1%) и TipTop (21,1%). Остальные источники привлекают 1,9-5,1% платящих пользователей. Меньше всего платящих пользователей пришло из YRabbit и MediaTornado.
#
#
# <li> Большая часть бюджета направляется на TipTop и FaceBoom, которые привлекают наибольшее количество клиентов. Однако FaceBoom оказывается более эффективным источником привлечения платящих клиентов. Наименее эффективными являются источники MediaTornado и YRabbit, в которые также вкладывается минимальное количество средств. В течение мая-сентября общий рекламный бюджет постепенно увеличивается, но в октябре начинает снижаться. Расходы на TipTop увеличиваются, но в последний месяц незначительно снижаются, оставаясь самыми высокими среди других источников. FaceBoom получает меньше бюджета, но эффективен в привлечении платящих клиентов. CAC (стоимость привлечения клиента) в источнике TipTop самый высокий, в то время как в других источниках стабильно низкий.
#
# <li> LTV продолжает расти, но ROI падает из-за увеличения стоимости привлечения пользователей. Реклама на данный момент не окупилась.
# Конверсия пользователей немного выше 8%, но снижается к концу месяца. Удержание платящих пользователей также снижается.
# LTV пользователей на PC самый низкий, но схож по остальным устройствам. LTV у пользователей из US выше, чем в других странах.
# Стоимость привлечения на iPhone и Mac растет быстрее, но окупаемость на PC выше, чем на других устройствах. Стоимость привлечения в US увеличивается постоянно, в других странах более стабильна.
# Наибольшая стоимость привлечения у источника TipTop, но окупаемость низкая.
# ROI снижается на PC и других устройствах, особенно в US.
# PC имеет самую низкую конверсию, а Mac и iPhone - самую высокую. Конверсия в US также выше, чем в других странах.
# Лучшее удержание пользователей на PC, а самое низкое - в US.

# %% [markdown]
# Ответы на вопросы из инструкции к выполнению проекта

# %% [markdown]
# 1. Реклама пока не окупилась, так как ROI падает из-за увеличения стоимости привлечения пользователей и снижения удержания платящих пользователей.
# 2. Платящие пользователи предпочитают iPhone, а на PC доля платящих пользователей самая низкая. Стоимость привлечения на iPhone и Mac растет быстрее, но окупаемость на PC выше, чем на других устройствах. В США стоимость привлечения увеличивается постоянно, в других странах она более стабильна.
# 3. Проблемы окупаемости могут быть вызваны увеличением стоимости привлечения пользователей, снижением конверсии и удержания платящих пользователей.

# %% [markdown]
# По проведенному анализу данных были выявлены следующие проблемы и рекомендации для рекламного отдела:
#
# 1. Количество платящих пользователей сильно разнится в зависимости от страны. США имеют самую высокую долю платящих пользователей (6,9%), а остальные страны - примерно одинаковую долю (3,8-4,1%). Следовательно, стоит более активно продвигать игру в США.
#
# 2. Пользователи iPhone составляют большую часть игроков (36,3%) и платящих пользователей (38,1%). Необходимо уделить особое внимание и продолжать развивать игру для устройств iPhone.
#
# 3. Источники привлечения пользователей - FaceBoom и TipTop - являются самыми эффективными, привлекая наибольшую долю платящих пользователей (40,1% и 21,1%). Нужно сосредоточиться на улучшении работы с этими источниками и продолжать вкладывать в них бюджет.
#
# 4. Бюджет на рекламу постепенно увеличивается, но в октябре начинает снижаться. Расходы на источник TipTop остаются самыми высокими, но эффективность его окупаемости находится на низком уровне. Следует проанализировать эффективность распределения бюджета и возможность снижения затрат на менее эффективные источники.
#
# 5. Общая конверсия пользователей составляет чуть больше 8%, но динамика конверсии на 14-й день непостоянна. Необходимо уделить внимание улучшению конверсии, особенно в конце месяца.
#
# 6. LTV клиентов растет и имеет наибольшую ценность у пользователей из США и клиентов, привлеченных из источников LambdaMediaAds и TipTop. Эти данные говорят о потенциале этих источников в долгосрочной эффективности.
#
# 7. ROI находится ниже уровня окупаемости, особенно в США. Динамика ROI показывает отрицательную тенденцию на 14-й день во всех регионах, что говорит о неэффективности текущих маркетинговых стратегий. Советуется пересмотреть эти стратегии и осуществить изменения.
#
# 8. Удержание платящих пользователей наблюдается на наименьшем уровне в США и требует повышения. Также стоит обратить внимание на удержание пользователей, привлеченных из источников FaceBoom и AdNonSense.

# %% [markdown]
# Так как пользователи из США являются преоблажающим большинством в выборке и их показатели существенно отличаются, возможно их стоит проанализировать дополнительно.
# При необходимости проведения анализа только по США - пожалуйста, дайте соответствующий комментарий
